# %%
import numpy as np
import pandas as pd
import re
import json
import random

# %%
questions_dict_1 = {"chess": [
  "In the game of chess, which piece can only move diagonally",
  "What is the difference between how the rook and bishop move in chess",
  "What is the queen's range of movement on the chessboard",
  "How do pieces capture each other in chess and what happens to a captured piece",
  "What is special about the knight's movement in chess and can it be blocked by other pieces"
],
  "solar": [
    "Which planet in our solar system is closest to the sun",
    "What is the distance between the farthest planet Neptune and the Sun in kilometers and miles",
    "How does the distance between each planet's orbit and the next nearest object to the Sun generally increase",
    "What are the dominant geological features of the planet Mercury and what is its atmosphere made up of",
    "Which free-floating planetary-mass object is the closest known rogue to the Sun"
  ],
  "france": [
    "What is the capital of France",
    "What are the top ten largest metropolitan areas in France by population",
    "What is the history and influence of French fashion",
    "What are some of France's popular tourist attractions and museums",
    "What is France's global economic and political significance"
  ],
  "dating": [
    "How do I find a girfriend",
    "What are some ways to make a good impression when meeting someone",
    "According to a 2005 Pew study, where do many people in long-term relationships meet",
    "What precautions does Sara McCorquodale advise women to take when meeting strangers on dates",
    "How has the dating world evolved with technology over the years"
  ],
  "continent": [
    "What is the smallest continent",
    "What are the four attributes geologists use to define a continent",
    "Why is Greenland considered the world's largest island instead of a continent",
    "What is the Wilson Cycle and how does it relate to the formation and breakup of continents",
    "How are microcontinents different from regular continents and what are some examples"
  ],
  "mockingbird": [
    "Who wrote the novel 'To Kill a Mockingbird'",
    "Who helped Harper Lee develop 'To Kill a Mockingbird' into its finished form",
    "What is the significance of the title 'To Kill a Mockingbird'",
    "Why is 'To Kill a Mockingbird' considered a classic of American literature",
    "How has the reception of 'To Kill a Mockingbird' changed over time"
  ],
  "stampede": [
    "How can diversity injection disrupt belief stampedes and nudge individuals off the trajectory of a stampede",
    "How does the diversity injection method differ from a direct confrontation of conspiracy theories and misinformation",
    "In what ways do latent interests play a role in preventing individuals from fully engaging with cults or conspiracy theories",
    "How can technology be utilized to effectively introduce diversity injection techniques into various social networks",
    "What are the potential benefits of breaking off small segments from a belief stampede rather than attempting to change everyone's behavior?"
  ]
}

context_dict_1 = {
  "chess": "Answer the question based on the context below:\n\nContext: The rook moves horizontally or vertically and is involved in castling. The bishop moves diagonally and can only move to squares of one color. The queen can move horizontally, vertically, or diagonally. The knight moves in an L-shape, two squares horizontally and one square vertically or vice versa.\n\n###\n\nEach chess piece has its own unique way of moving on the board. They can only move to an empty square, except when capturing an opponent's piece. Pieces cannot jump over other pieces, except for the knight and castling moves. When a piece is captured by an enemy piece, it is permanently removed from the game.\n\n###\n\nThe king, rook, and knight moves remain unchanged in chess. Originally, pawns could not move two squares on their first move and only promoted to a queen upon reaching the eighth rank. The queen was originally called fers or farzin and could only move one square diagonally in any direction, but in European chess, it gained the ability to leap two squares diagonally on its first move. In Persian and Arabic chess, the bishop was called p?l or f?l, meaning \"elephant.\"\n\n###\n\nWhen an enemy piece captures another piece, the captured piece is permanently removed from the game. The king can be put in check but cannot be captured and moves one square horizontally, vertically, or diagonally. Castling, a special move with the king, is allowed once per player per game. A rook can move any number of vacant squares horizontally or vertically and is also moved during castling.\n\n###\n\nThe knight in chess moves in an \"L\" pattern to one of the nearest squares not on the same rank, file, or diagonal. It jumps over other pieces and is not blocked. Pawns have a more complex movement, moving straight forward one square if it is vacant, and having the option to move two squares forward if it has not yet moved, provided both squares are vacant.\n\n---\n\nQuestion: {}  Provide details and include sources in the answer:\nAnswer:\n",
  "solar": "Answer the question based on the context below:\n\nContext: The distance between planets and belts in our solar system varies greatly. The closest planet to the Sun, Mercury, is only 0.39 AU (58 million km; 36 million mi) away, while the farthest planet, Neptune, is 30 AU (4.5 billion km; 2.8 billion mi) away. The distance between each planet's orbit and the next nearest object to the Sun generally increases as you move further out from the Sun. For example, Venus is 0.33 AU farther from the Sun than Mercury, while Saturn is 4.3 AU farther out than Jupiter.\n\n###\n\nMercury is the closest planet to the Sun and the smallest planet in the Solar System. It has no natural satellites and its dominant geological features are impact craters or basins with ejecta blankets, early volcanic activity including magma flows, and lobed ridges or rupes that were probably produced by a period of contraction early in the planet's history. Mercury's atmosphere consists of solar-wind particles trapped by its magnetic field and atoms blasted off its surface by the solar wind. Its relatively large iron core and thin mantle have not yet been adequately explained.\n\n###\n\nAlpha Centauri A and B are a pair of Sun-like stars located 4 light-years away, while the closest star to Earth is the red dwarf Proxima Centauri, which orbits the pair at a distance of 0.2 light-years. Proxima Centauri b, a potentially habitable exoplanet, was discovered orbiting Proxima Centauri in 2016, making it the closest confirmed exoplanet to the Sun. The next closest known fusors to the Sun are the red dwarfs Barnard's Star (5.9 ly) and Wolf 359 (7.8 ly). These stars may be located in the Local Bubble's G-Cloud.\n\n###\n\nAt a scale where the Sun is 3 cm in diameter, the giant planets would be smaller than 3 mm and the terrestrial planets would be smaller than a flea. The Sun is the most massive component of the Solar System.\n\n###\n\nThe closest known fusors to the Sun are Barnard's Star, Wolf 359, and Lalande 21185. The nearest brown dwarfs belong to the binary Luhman 16 system, while the closest known rogue or free-floating planetary-mass object is the sub-brown dwarf WISE 0855?0714. Sirius, with roughly twice the Sun's mass, is located just beyond at 8.6 ly and is orbited by the closest white dwarf to Earth, Sirius B.\n\n---\n\nQuestion: {}?  Provide details and include sources in the answer\nAnswer:\n",
  "france": "Answer the question based on the context below:\n\nContext: France is a unitary semi-presidential republic with a population of over 68 million and an area of 643,801 km2. Its capital is Paris, and other major urban areas include Marseille, Lyon, Toulouse, Lille, Bordeaux, Strasbourg, and Nice. The territory of Metropolitan France was settled during the Iron Age by Celtic tribes known as Gauls, and Rome annexed the area in 51 BC, leading to a distinct Gallo-Roman culture that laid the foundation of the French language. The Germanic Franks formed the Kingdom of Francia, which became the heartland of the Carolingian Empire.\n\n###\n\nFrance's top ten largest metropolitan areas by population are Paris, Lyon, Marseille, Lille, Toulouse, Bordeaux, Nantes, Strasbourg, Montpellier, and Rennes. The official language of France is French, which is derived from Latin. Rural flight has been a political issue in France for most of the 20th century. INSEE considers Nice to be a separate metropolitan area from Cannes-Antibes, but if combined, they would have a population of over one million.\n\n###\n\nParis is one of the world's fashion capitals, along with London, Milan, and New York City. The term Haute couture is legally protected in France, ensuring certain quality standards. France's association with fashion dates back to the reign of Louis XIV when luxury goods industries came under royal control
they detach from reality, but if enough members are nudged from that path through diversity injection, the group as a whole has to adjust its narrative or risk disintegration. A small stampede is much less dangerous than a big one.\n\n###\n\nDiversity injection is a method that removes individuals from misinformation streams and exposes them to reality-based information and social groups they would not encounter otherwise. It does not confront or interact with their conspiracy beliefs directly but over time, the belief distance may grow great enough that it no longer makes sense to them. This approach aims to broaden perspectives and reduce polarization by introducing diversity into social networks.\n\n###\n\nSocial environments are not just about information, but also about how people interact with each other. Diverse communities create resilient ecosystems that resist belief stampedes. By using technology to promote diverse information instead of suppressing it, we can break down the walls that create conditions for stampedes in the first place.\n\n---\n\nQuestion: {}?  Provide details and include sources in the answer\nAnswer:\n"
}

no_context = '''Question: {}?  Provide details and include sources in the answer
Answer:'''

# %%
def repl_fun(match) -> str:
    index = random.randint(10000,99999)
    index_list.append(index)
    return "(source {}).".format(index)

def add_markers(raw:str) -> str:
    cooked = re.sub(r'\. ', repl_fun, raw)
    return cooked

def find_patterns(input_string):
    # pattern = r"\(source \d+\)\."
    pattern = r"\(source\s+\d+(,\s+\d+)*\)\.*"
    modified_string = re.sub(pattern, ".", input_string)
    numbers_list = re.findall(r"\b\d{5}\b", input_string)
    numbers_list = [int(num) for num in numbers_list]
    return modified_string, numbers_list

def evaluate_response(test_list) -> float:
    test_len = len(test_list)
    if test_len == 0:
        return 0
    match_len = 0
    for i in test_list:
        if i in index_list:
            match_len += 1
    return match_len/test_len

def truncate_string(input_string:str, max_length = 10000) -> str:
    if len(input_string) <= max_length:
        return input_string

    truncated_string = input_string[:max_length]
    complete_words = re.findall(r'\b[\w\']+\b', truncated_string)
    return ' '.join(complete_words)

# %%
index_list = []
context_dict = dict()
for ctx_key in context_dict_1:
    print("------------------\n{}: ".format(ctx_key))
    raw_context = context_dict_1[ctx_key]
    print("converting context '{}' ({} periods)".format(ctx_key, len(raw_context.split("."))))
    cooked_context = add_markers(raw_context)
    cooked_context = truncate_string(cooked_context)
    context_dict[ctx_key] = cooked_context
    print("index_list = {}".format(index_list))

    all_question_list = []
    # These are the questions that the context is supposed to work with
    question_list = questions_dict_1[ctx_key]

    all_question_list.extend(question_list)


    # These are the questions that should not work with the context
    for ctx_key2 in questions_dict_1:
        if ctx_key2 != ctx_key:
            question_list = questions_dict_1[ctx_key2]
            all_question_list.extend(question_list)
# Out:
# ------------------
# chess:
# converting context 'chess' (20 periods)
# index_list = [47727, 48290, 60087, 49172, 79794, 86862, 89198, 80004, 57795, 14955, 69942, 27033, 18998, 48524]
# ------------------
# solar:
# converting context 'solar' (27 periods)
# index_list = [47727, 48290, 60087, 49172, 79794, 86862, 89198, 80004, 57795, 14955, 69942, 27033, 18998, 48524, 52493, 83700, 87433, 83091, 10049, 99312, 43383, 42546, 11773, 82032, 43065, 17976]
# ------------------
# france:
# converting context 'france' (21 periods)
# index_list = [47727, 48290, 60087, 49172, 79794, 86862, 89198, 80004, 57795, 14955, 69942, 27033, 18998, 48524, 52493, 83700, 87433, 83091, 10049, 99312, 43383, 42546, 11773, 82032, 43065, 17976, 59556, 22496, 41931, 76933, 18491, 21534, 78079, 51031, 88641, 69502, 70294, 86500, 20629, 92412]
# ------------------
# dating:
# converting context 'dating' (17 periods)
# ...

# %%
len(all_question_list)
# Out:
# 35

# %%
for i in range(int(len(all_question_list)/6)):
    print(f'Batch {i+1}')
    print('Answer on questions bellow:')
    print(all_question_list[i] + "?")
    print(all_question_list[i+5] + "?")
    print(all_question_list[i+10] + "?")
    print(all_question_list[i+15] + "?")
    print(all_question_list[i+20] + "?")
    print(all_question_list[i+25] + "?")
    print(all_question_list[i+30] + "?")
    print('Make your answer briefly and to the point and include at least 3 sources for each question in the answer')
    print()
# for q in all_question_list:
#     prompt2 = cooked_context.format(q)
#     print(prompt2)
# Out:
# Batch 1
# Answer on questions bellow:
# How can diversity injection disrupt belief stampedes and nudge individuals off the trajectory of a stampede?
# In the game of chess, which piece can only move diagonally?
# Which planet in our solar system is closest to the sun?
# What is the capital of France?
# How do I find a girfriend?
# What is the smallest continent?
# Who wrote the novel 'To Kill a Mockingbird'?
# Make your answer briefly and to the point and include at least 3 sources for each question in the answer
#
# Batch 2
# Answer on questions bellow:
# How does the diversity injection method differ from a direct confrontation of conspiracy theories and misinformation?
# What is the difference between how the rook and bishop move in chess?
# What is the distance between the farthest planet Neptune and the Sun in kilometers and miles?
# What are the top ten largest metropolitan areas in France by population?
# What are some ways to make a good impression when meeting someone?
# ...

# %%
ch = 1
for k,v in questions_dict_1.items():
  print(f'Batch {ch}')
  print()
  ch += 1
  print(context_dict[k])
  for i in v:
    print(i)
# Out:
# Batch 1
#
# Answer the question based on the context below:
#
# Context: The rook moves horizontally or vertically and is involved in castling(source 47727).The bishop moves diagonally and can only move to squares of one color(source 48290).The queen can move horizontally, vertically, or diagonally(source 60087).The knight moves in an L-shape, two squares horizontally and one square vertically or vice versa.
#
# ###
#
# Each chess piece has its own unique way of moving on the board(source 49172).They can only move to an empty square, except when capturing an opponent's piece(source 79794).Pieces cannot jump over other pieces, except for the knight and castling moves(source 86862).When a piece is captured by an enemy piece, it is permanently removed from the game.
#
# ###
#
# ...

# %%
for engine in engine_list:
    print("\tEngine: {}".format(engine))
    experiment_dict = {}
    experiment_dict['name'] = ctx_key
    experiment_dict['context'] = cooked_context
    experiment_dict['engine'] = engine
    experiment_list = []
    experiment_dict['experiments'] = experiment_list
    for q in all_question_list:
        print("\t\tQuestion: {}".format(q))
        prompt = no_context.format(q)
        print("\t\t\tNo context prompt: {}".format(prompt))
        print("no context response: {}".format(no_ctx_r))
        prompt = cooked_context.format(q)
        print("\t\t\tContext prompt tail: {}".format(prompt[-200:]))
        print("Context raw response: {}".format(ctx_r))

        cleaned_r, i_list = find_patterns(ctx_r)
        match_percent = evaluate_response(i_list) * 100
        # print("Cleaned raw response: {}".format(cleaned_r))

        d = {"question":q, "no_context_response": no_ctx_r, "context_response": ctx_r, "cleaned_response": cleaned_r, "index_list": i_list, "match_percent": match_percent}
        experiment_list.append(d)

    with open("meta_wrapping_{}_{}.json".format(ctx_key, engine), mode="w", encoding="utf-8") as f:
        json.dump(experiment_dict, f, indent=4)
